# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourpatil123/Learn_Pandas/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
cd = pd.read_csv('mtcars.csv')
cd
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cd.manufacturer
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
cd[['manufacturer']]
# Out:
#            manufacturer
# 0             Mazda RX4
# 1         Mazda RX4 Wag
# 2            Datsun 710
# 3        Hornet 4 Drive
# 4     Hornet Sportabout
# 5               Valiant
# 6            Duster 360
# 7             Merc 240D
# 8              Merc 230
# 9              Merc 280
# 10            Merc 280C
# 11           Merc 450SE
# 12           Merc 450SL
# 13          Merc 450SLC
# 14   Cadillac Fleetwood
# 15  Lincoln Continental
# 16    Chrysler Imperial
# 17             Fiat 128
# 18          Honda Civic
# 19       Toyota Corolla
# 20        Toyota Corona
# 21     Dodge Challenger
# 22          AMC Javelin
# 23           Camaro Z28
# 24     Pontiac Firebird
# 25            Fiat X1-9
# 26        Porsche 914-2
# 27         Lotus Europa
# 28       Ford Pantera L
# 29         Ferrari Dino
# 30        Maserati Bora
# 31           Volvo 142E

# %%
cd['manufacturer'].unique()
# Out:
# array(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D',
#        'Merc 230', 'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL',
#        'Merc 450SLC', 'Cadillac Fleetwood', 'Lincoln Continental',
#        'Chrysler Imperial', 'Fiat 128', 'Honda Civic', 'Toyota Corolla',
#        'Toyota Corona', 'Dodge Challenger', 'AMC Javelin', 'Camaro Z28',
#        'Pontiac Firebird', 'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa',
#        'Ford Pantera L', 'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype=object)

# %%
cd[['manufacturer','cyl','hp']]
# Out:
#            manufacturer  cyl   hp
# 0             Mazda RX4    6  110
# 1         Mazda RX4 Wag    6  110
# 2            Datsun 710    4   93
# 3        Hornet 4 Drive    6  110
# 4     Hornet Sportabout    8  175
# 5               Valiant    6  105
# 6            Duster 360    8  245
# 7             Merc 240D    4   62
# 8              Merc 230    4   95
# 9              Merc 280    6  123
# 10            Merc 280C    6  123
# 11           Merc 450SE    8  180
# 12           Merc 450SL    8  180
# 13          Merc 450SLC    8  180
# 14   Cadillac Fleetwood    8  205
# 15  Lincoln Continental    8  215
# 16    Chrysler Imperial    8  230
# 17             Fiat 128    4   66
# 18          Honda Civic    4   52
# 19       Toyota Corolla    4   65
# 20        Toyota Corona    4   97
# 21     Dodge Challenger    8  150
# 22          AMC Javelin    8  150
# 23           Camaro Z28    8  245
# 24     Pontiac Firebird    8  175
# 25            Fiat X1-9    4   66
# ...

# %%
cd.iloc[0:4:1,0:4:1]
# Out:
#      manufacturer   mpg  cyl   disp
# 0       Mazda RX4  21.0    6  160.0
# 1   Mazda RX4 Wag  21.0    6  160.0
# 2      Datsun 710  22.8    4  108.0
# 3  Hornet 4 Drive  21.4    6  258.0

# %%
cd.iloc[:,:]
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cd.iloc[-5:,:5]
# Out:
#       manufacturer   mpg  cyl   disp   hp
# 27    Lotus Europa  30.4    4   95.1  113
# 28  Ford Pantera L  15.8    8  351.0  264
# 29    Ferrari Dino  19.7    6  145.0  175
# 30   Maserati Bora  15.0    8  301.0  335
# 31      Volvo 142E  21.4    4  121.0  109

# %%
cd.iloc[0::2,1::2]
# Out:
#      mpg   disp  drat   qsec  am  carb
# 0   21.0  160.0  3.90  16.46   1     4
# 2   22.8  108.0  3.85  18.61   1     1
# 4   18.7  360.0  3.15  17.02   0     2
# 6   14.3  360.0  3.21  15.84   0     4
# 8   22.8  140.8  3.92  22.90   0     2
# 10  17.8  167.6  3.92  18.90   0     4
# 12  17.3  275.8  3.07  17.60   0     3
# 14  10.4  472.0  2.93  17.98   0     4
# 16  14.7  440.0  3.23  17.42   0     4
# 18  30.4   75.7  4.93  18.52   1     2
# 20  21.5  120.1  3.70  20.01   0     1
# 22  15.2  304.0  3.15  17.30   0     2
# 24  19.2  400.0  3.08  17.05   0     2
# 26  26.0  120.3  4.43  16.70   1     2
# 28  15.8  351.0  4.22  14.50   1     4
# 30  15.0  301.0  3.54  14.60   1     8

# %%
cd.iloc[[2,3,7,4,6,9],[1,5,4manufacturer]]
# Out:
#     mpg  drat   hp
# 2  22.8  3.85   93
# 3  21.4  3.08  110
# 7  24.4  3.69   62
# 4  18.7  3.15  175
# 6  14.3  3.21  245
# 9  19.2  3.92  123

# %%
cd.loc[:,['mpg','disp','am','gear']]
# Out:
#      mpg   disp  am  gear
# 0   21.0  160.0   1     4
# 1   21.0  160.0   1     4
# 2   22.8  108.0   1     4
# 3   21.4  258.0   0     3
# 4   18.7  360.0   0     3
# 5   18.1  225.0   0     3
# 6   14.3  360.0   0     3
# 7   24.4  146.7   0     4
# 8   22.8  140.8   0     4
# 9   19.2  167.6   0     4
# 10  17.8  167.6   0     4
# 11  16.4  275.8   0     3
# 12  17.3  275.8   0     3
# 13  15.2  275.8   0     3
# 14  10.4  472.0   0     3
# 15  10.4  460.0   0     3
# 16  14.7  440.0   0     3
# 17  32.4   78.7   1     4
# 18  30.4   75.7   1     4
# 19  33.9   71.1   1     4
# 20  21.5  120.1   0     3
# 21  15.5  318.0   0     3
# 22  15.2  304.0   0     3
# 23  13.3  350.0   0     3
# 24  19.2  400.0   0     3
# 25  27.3   79.0   1     4
# 26  26.0  120.3   1     5
# 27  30.4   95.1   1     5
# 28  15.8  351.0   1     5
# 29  19.7  145.0   1     5
# 30  15.0  301.0   1     5
# 31  21.4  121.0   1     4

# %%
cd.loc[:4,:'hp']
# Out:
#         manufacturer   mpg  cyl   disp   hp
# 0          Mazda RX4  21.0    6  160.0  110
# 1      Mazda RX4 Wag  21.0    6  160.0  110
# 2         Datsun 710  22.8    4  108.0   93
# 3     Hornet 4 Drive  21.4    6  258.0  110
# 4  Hornet Sportabout  18.7    8  360.0  175

# %%
cd.gear.unique()
# Out:
# array([4, 3, 5])

# %%
cd.gear.value_counts()
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
cd[cd['gear']==5]
# Out:
#       manufacturer   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.7   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
#
#     carb
# 26     2
# 27     2
# 28     4
# 29     6
# 30     8

# %%
cd[(cd['gear']==4) | (cd['gear']==3)]
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...
